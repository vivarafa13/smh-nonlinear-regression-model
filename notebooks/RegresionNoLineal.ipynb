# %% [markdown]
# <a href="https://colab.research.google.com/github/vivarafa13/smh-nonlinear-regression-model/blob/main/notebooks/RegresionNoLineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# 1. Montar Google Drive para tener acceso a tus carpetas
from google.colab import drive
drive.mount('/content/drive')

# 2. Definir la ruta exacta de tu archivo en Drive
# (Asumiendo que '03 Ejercicios' está en la raíz de tu unidad principal 'My Drive')
ruta_drive = '/content/drive/MyDrive/Classroom/IFTS18 TSCDIA Modelizado de sistemas de AI/03 Ejercicios/Proyecto 5/Master_Model.csv'

# 3. Cargar el archivo CSV desde Drive
df = pd.read_csv(ruta_drive)

# 4. Convertir la fecha a formato datetime de Python
df['Master_Date'] = pd.to_datetime(df['Master_Date'])

# 5. Limpiar la columna de porcentaje para transformarla en número real
df['Retorno_3m'] = df['Retorno_3m'].astype(str).str.replace('%', '')
df['Retorno_3m'] = pd.to_numeric(df['Retorno_3m'], errors='coerce') / 100

# 6. SEPARAR EL DATASET PARA EL MODELADO
df_train = df.dropna(subset=['Retorno_3m']).copy()
df_predict = df[df['Retorno_3m'].isna()].copy()

print("--- DATASET DE ENTENTRAMIENTO (Listo para la Regresión) ---")
print(df_train.tail())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --- DATASET DE ENTENTRAMIENTO (Listo para la Regresión) ---
#   Master_Date     SMH    NASDAQ  VIXCLS  FEDFUNDS  CPIAUCSL  Retorno_3m
# 4  2025-10-31  363.02  23724.96   15.77      4.09   324.654      0.1114
# 5  2025-11-30  352.28  23365.69   14.85      3.88   325.063      0.1535
# 6  2025-12-31  360.13  23241.99   15.74      3.72   326.031      0.0646
# 7  2026-01-31  403.46  23461.82   20.00      3.64   326.588      0.2559
# 8  2026-02-28  406.37  22668.21   19.83      3.64   327.460      0.4739
